# %% [markdown]
# # Working with parquet files
#
# ## Objective
#
# + In this assignment, we will use the data downloaded with the module `data_manager` to create features.
#
# (11 pts total)
#
# ## Prerequisites
#
# + This notebook assumes that price data is available to you in the environment variable `PRICE_DATA`. If you have not done so, then execute the notebook `01_materials/labs/2_data_engineering.ipynb` to create this data set.

# %% [markdown]
# + Load the environment variables using dotenv. (1 pt)

# %%
# Write your code below.
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import dask.dataframe as dd

# %% [markdown]
# + Load the environment variable `PRICE_DATA`.
# + Use [glob](https://docs.python.org/3/library/glob.html) to find the path of all parquet files in the directory `PRICE_DATA`.
#
# (1pt)

# %%
import os
import sys
from glob import glob
sys.path.append(os.getenv("SRC_DIR"))
from utils.logger import get_logger
_logs = get_logger(__name__)

price_data_dir = os.getenv('PRICE_DATA')
_logs.info(f"PRICE_DATA dir: {price_data_dir}")

parquet_files = glob(os.path.join(price_data_dir, "**/*.parquet"), recursive=True)

parquet_files
# Out:
# 2025-10-01 22:33:05,073, 3224500147.py, 9, INFO, PRICE_DATA dir: ../../05_src/data/prices/
# ['../../05_src/data/prices\\ACN\\ACN_2001\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2001\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2002\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2002\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2003\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2003\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2004\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2004\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2005\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2005\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2006\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2006\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2007\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2007\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2008\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2008\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2009\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2009\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2010\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2010\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2011\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2011\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2012\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2012\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2013\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2013\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ALDX\\ALDX_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1993\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1993\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1994\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1994\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1995\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1995\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1996\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1996\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1997\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1997\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1998\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1998\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1999\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_1999\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2000\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2000\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2001\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2001\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2002\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2002\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2003\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2003\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2004\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2004\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2005\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2005\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2006\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2006\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2007\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2007\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2008\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2008\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2009\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2009\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2010\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2010\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2011\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2011\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2012\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2012\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2013\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2013\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2000\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2000\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2001\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2001\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2002\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2002\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2003\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2003\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2004\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2004\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2005\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2005\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2006\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2006\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2007\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2007\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2008\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2008\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2009\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2009\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2010\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2010\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2011\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2011\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2012\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2012\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2013\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2013\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ALT\\ALT_2020\\part.1.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2018\\part.0.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2018\\part.1.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2019\\part.0.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2019\\part.1.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2020\\part.0.parquet',
#  '../../05_src/data/prices\\AMAL\\AMAL_2020\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2013\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2013\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2014\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2014\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2015\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2015\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2016\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2016\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2017\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2017\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2018\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2018\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2019\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2019\\part.1.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2020\\part.0.parquet',
#  '../../05_src/data/prices\\AMH\\AMH_2020\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2015\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2015\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2016\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2016\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2017\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2017\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2018\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2018\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2019\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2019\\part.1.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2020\\part.0.parquet',
#  '../../05_src/data/prices\\AQMS\\AQMS_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2007\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2007\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2008\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2008\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2009\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2009\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2010\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2010\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2011\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2011\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2012\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2012\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2013\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2013\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ARAY\\ARAY_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ARGX\\ARGX_2020\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2007\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2007\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2008\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2008\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2009\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2009\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2010\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2010\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2011\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2011\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2012\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2012\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2013\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2013\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2014\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2014\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2015\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2015\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2016\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2016\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2017\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2017\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2018\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2018\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2019\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2019\\part.1.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2020\\part.0.parquet',
#  '../../05_src/data/prices\\ATHX\\ATHX_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BGB\\BGB_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2007\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2007\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2008\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2008\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2009\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2009\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2010\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2010\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2011\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2011\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BGS\\BGS_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BILI\\BILI_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2006\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2006\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2007\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2007\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2008\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2008\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2009\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2009\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2010\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2010\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2011\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2011\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BIMI\\BIMI_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BLPH\\BLPH_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BOTZ\\BOTZ_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BPMX\\BPMX_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BPYPN\\BPYPN_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BPYPN\\BPYPN_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BRQS\\BRQS_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BSTZ\\BSTZ_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BSTZ\\BSTZ_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BSTZ\\BSTZ_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BSTZ\\BSTZ_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BUYN\\BUYN_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2005\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2005\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2006\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2006\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2007\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2007\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2008\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2008\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2009\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2009\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2010\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2010\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2011\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2011\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BWEN\\BWEN_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BWG\\BWG_2020\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2007\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2007\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2008\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2008\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2009\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2009\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2010\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2010\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2011\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2011\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2012\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2012\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2013\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2013\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2014\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2014\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2015\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2015\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2016\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2016\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2017\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2017\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2018\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2018\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2019\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2019\\part.1.parquet',
#  '../../05_src/data/prices\\BX\\BX_2020\\part.0.parquet',
#  '../../05_src/data/prices\\BX\\BX_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1980\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1980\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1981\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1981\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1982\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1982\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1983\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1983\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1984\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1984\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1985\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1985\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1986\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1986\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1987\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1987\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1988\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1988\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1989\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1989\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1990\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1990\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1991\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1991\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1992\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1992\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1993\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1993\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1994\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1994\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1995\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1995\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1996\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1996\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1997\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1997\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1998\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1998\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1999\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_1999\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CBB\\CBB_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CEQP\\CEQP_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CGEN\\CGEN_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1997\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1997\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1998\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1998\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1999\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_1999\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CHL\\CHL_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CIIC\\CIIC_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CIIC\\CIIC_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CLVS\\CLVS_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CMCTP\\CMCTP_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CNS\\CNS_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1987\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1987\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1988\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1988\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1989\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1989\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1990\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1990\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1991\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1991\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1992\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1992\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1993\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1993\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1994\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1994\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1995\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1995\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1996\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1996\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1997\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1997\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1998\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1998\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1999\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_1999\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CRMT\\CRMT_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CSSE\\CSSE_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CSWI\\CSWI_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1987\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1987\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1988\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1988\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1989\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1989\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1990\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1990\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1991\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1991\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1992\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1992\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1993\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1993\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1994\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1994\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1995\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1995\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1996\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1996\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1997\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1997\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1998\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1998\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1999\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_1999\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CTBI\\CTBI_2020\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1992\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1992\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1993\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1993\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1994\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1994\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1995\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1995\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1996\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1996\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1997\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1997\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1998\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1998\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1999\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_1999\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2000\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2000\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2001\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2001\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2002\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2002\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2003\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2003\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2004\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2004\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2005\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2005\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2006\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2006\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2007\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2007\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2008\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2008\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2009\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2009\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2010\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2010\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2011\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2011\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2012\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2012\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2013\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2013\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2014\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2014\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2015\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2015\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2016\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2016\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2017\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2017\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2018\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2018\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2019\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2019\\part.1.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2020\\part.0.parquet',
#  '../../05_src/data/prices\\CVU\\CVU_2020\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2006\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2006\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2007\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2007\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2008\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2008\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2009\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2009\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2010\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2010\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2011\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2011\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2012\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2012\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2013\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2013\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2014\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2014\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2015\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2015\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2016\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2016\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2017\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2017\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2018\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2018\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2019\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2019\\part.1.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2020\\part.0.parquet',
#  '../../05_src/data/prices\\DEW\\DEW_2020\\part.1.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2006\\part.0.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2006\\part.1.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2007\\part.0.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2007\\part.1.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2008\\part.0.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2008\\part.1.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2009\\part.0.parquet',
#  '../../05_src/data/prices\\DFJ\\DFJ_2009\\part.1.parquet',
#  ...]

# %% [markdown]
# For each ticker and using Dask, do the following:
#
# + Add lags for variables Close and Adj_Close.
# + Add returns based on Close:
#
#     - `returns`: (Close / Close_lag_1) - 1
#
# + Add the following range:
#
#     - `hi_lo_range`: this is the day's High minus Low.
#
# + Assign the result to `dd_feat`.
#
# (4 pt)

# %%
dd_feat = dd.read_parquet(parquet_files)

dd_feat['Close_lag_1'] = dd_feat.groupby('ticker')['Close'].shift(1)
dd_feat['Adj_Close_lag_1'] = dd_feat.groupby('ticker')['Adj Close'].shift(1)

dd_feat['returns'] = (dd_feat['Close'] / dd_feat['Close_lag_1']) - 1

dd_feat['hi_lo_range'] = dd_feat['High'] - dd_feat['Low']

dd_feat.head()
# Out:
# C:\Users\samoj\AppData\Local\Temp\ipykernel_33184\2927084435.py:3: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_feat['Close_lag_1'] = dd_feat.groupby('ticker')['Close'].shift(1)
# C:\Users\samoj\AppData\Local\Temp\ipykernel_33184\2927084435.py:4: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_feat['Adj_Close_lag_1'] = dd_feat.groupby('ticker')['Adj Close'].shift(1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 10
#       6 dd_feat['returns'] = (dd_feat['Close'] / dd_feat['Close_lag_1']) - 1
#       8 dd_feat['hi_lo_range'] = dd_feat['High'] - dd_feat['Low']
# ---> 10 dd_feat.head()
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_collection.py:703, in FrameBase.head(self, n, npartitions, compute)
#     701 out = new_collection(expr.Head(self, n=n, npartitions=npartitions))
#     702 if compute:
# --> 703     out = out.compute()
#     704 return out
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_collection.py:477, in FrameBase.compute(self, fuse, **kwargs)
#     475     out = out.repartition(npartitions=1)
#     476 out = out.optimize(fuse=fuse)
# --> 477 return DaskMethodsMixin.compute(out, **kwargs)
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:376, in DaskMethodsMixin.compute(self, **kwargs)
#     352 def compute(self, **kwargs):
#     353     """Compute this dask collection
#     354
#     355     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     374     dask.compute
#     375     """
# --> 376     (result,) = compute(self, traverse=False, **kwargs)
#     377     return result
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# + Convert the Dask data frame to a pandas data frame.
# + Add a new feature containing the moving average of `returns` using a window of 10 days. There are several ways to solve this task, a simple one uses `.rolling(10).mean()`.
#
# (3 pt)

# %%
# Write your code below.
df_feat = dd_feat.compute()

df_feat = df_feat.sort_values(['ticker', 'Date'])


df_feat["returns_MovAv_10"] = df_feat['returns'].rolling(10).mean()



df_feat.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Write your code below.
# ----> 2 df_feat = dd_feat.compute()
#       4 df_feat = df_feat.sort_values(['ticker', 'Date'])
#       7 df_feat['returns'].rolling(10).mean()
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_collection.py:477, in FrameBase.compute(self, fuse, **kwargs)
#     475     out = out.repartition(npartitions=1)
#     476 out = out.optimize(fuse=fuse)
# --> 477 return DaskMethodsMixin.compute(out, **kwargs)
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:376, in DaskMethodsMixin.compute(self, **kwargs)
#     352 def compute(self, **kwargs):
#     353     """Compute this dask collection
#     354
#     355     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     374     dask.compute
#     375     """
# --> 376     (result,) = compute(self, traverse=False, **kwargs)
#     377     return result
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File c:\Users\samoj\miniconda3\envs\dsi_participant\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Please comment:
#
# + Was it necessary to convert to pandas to calculate the moving average return?
# + Would it have been better to do it in Dask? Why?
#
# (1 pt)

# %% [markdown]
# No, it could have been done on Dask as well. Given the large size of this dataset, it might have been better in Dask.

# %% [markdown]
# ## Criteria
#
# The [rubric](./assignment_1_rubric_clean.xlsx) contains the criteria for grading.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
